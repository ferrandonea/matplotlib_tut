# %% [markdown]
# # Tutorial
# https://www.youtube.com/watch?v=wB9C0Mz9gSo&t=847s
#
# https://github.com/derekbanas/matplotlib

# %% [markdown]
# ## Imports

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

#esto es para hacer auto reload
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Functional Plot

# %%
x_1 = np.linspace(0,5,10)
y_1 = x_1**2

plt.plot(x_1,y_1)
plt.title("Days Squared Chart")
plt.xlabel("Days")
plt.ylabel("Days Squared")
plt.show()

# %% [markdown]
# ## Print Multiple Plots

# %%
plt.subplot(1,2,1) #el 1 de 1 row y 2 columns
plt.plot(x_1,y_1,'r')
plt.show()

# %%
plt.subplot(1,2,1) #el 1 de 1 row y 2 columns
plt.plot(x_1,y_1,'r')
plt.subplot(1,2,2) #el 2 de 1 row y 2 columns
plt.plot(x_1,y_1,'b')
plt.show()

# %% [markdown]
# ## Figure Object
#
# Figure es un objeto que contiene todos los elementos del plot, puede tener múltiples axis

# %%
fig_1 = plt.figure(figsize=(5,4), dpi=100)  #figzise en pulgadas
axes_1 = fig_1.add_axes([0.1,0.1,0.9,0.9]) #left bottom, width y height en porcentaje
#([a,b,c,d]) donde (a,b) is the point in southwest corner of the rectangle which we create. c represents width and d represents height of the respective rectangle.
axes_1.set_xlabel("Days")
axes_1.set_ylabel("Days Squared")
axes_1.set_title("Days Squared Chart")
axes_1.plot(x_1,y_1,'r', label="x/x2")
axes_1.plot(y_1,x_1,'b', label="x2/x")
axes_1.legend(loc=0) 
# 0 es best location, 1 es upper right, 2 upper left, 3 lower left, 4 lower right
# se puede dat tupla de (x,y) desde el lower left
plt.show()

# %% [markdown]
# Hagamos un gráfico dentro de otro grafico, o un axis en otro axis

# %%
fig_1 = plt.figure(figsize=(5,4), dpi=100) 
axes_1 = fig_1.add_axes([0.1,0.1,0.9,0.9]) 
axes_1.set_xlabel("Days")
axes_1.set_ylabel("Days Squared")
axes_1.set_title("Days Squared Chart")
axes_1.plot(x_1,y_1,'r', label="x/x2")
axes_1.plot(y_1,x_1,'b', label="x2/x")
axes_1.legend(loc=0) 

axes_2 = fig_1.add_axes([0.45,0.45,0.4,0.3])
axes_2.set_xlabel("Days")
axes_2.set_ylabel("Days Squared")
axes_2.set_title("Days Squared Chart")
axes_2.plot(x_1,y_1,'k')

plt.show()

# %% [markdown]
# un text message, base on center is 0,0

# %%
fig_1 = plt.figure(figsize=(5,4), dpi=100) 
axes_1 = fig_1.add_axes([0.1,0.1,0.9,0.9]) 
axes_1.set_xlabel("Days")
axes_1.set_ylabel("Days Squared")
axes_1.set_title("Days Squared Chart")
axes_1.plot(x_1,y_1,'r', label="x/x2")
axes_1.plot(y_1,x_1,'b', label="x2/x")
axes_1.legend(loc=0) 

axes_2 = fig_1.add_axes([0.45,0.45,0.4,0.3])
axes_2.set_xlabel("Days")
axes_2.set_ylabel("Days Squared")
axes_2.set_title("Days Squared Chart")
axes_2.plot(x_1,y_1,'k')

axes_2.text(0,4, "Message", color="r")
plt.show()

# %% [markdown]
# ## Subplots

# %%
fig2, axes_2 = plt.subplots(figsize=(8,4), nrows=1, ncols=3)
plt.tight_layout() #esto evita overlaps

axes_2[1].set_title("Plot 2")
axes_2[1].set_xlabel("X")
axes_2[1].set_ylabel("X Squared")
axes_2[1].plot(x_1,y_1)
plt.show()

# %% [markdown]
# ## Appearence Options

# %%
# Default colors (b: blue, g: green, r: red, c: cyan, m: magenta,
# y: yellow, k: black, w: white)
# color="0.75" creates a 75% gray
# You can use hexcodes color="#eeefff"
# You can use color names found next like this color="burlywood"
# https://en.wikipedia.org/wiki/Web_colors
# alpha defines the percentage of opacity

# The default line width is 1, so to double it put in 2 and so forth

# There are many line styles 
# matplotlib.org/3.1.0/gallery/lines_bars_and_markers/linestyles.html
# You can also provide a sample like '-.'

# Markers can mark your provided points on the graph
# https://matplotlib.org/3.3.0/api/markers_api.html
# You can change the markersize as well

# markerfacecolor changes the marker fill color
# markeredgecolor changes the marker stroke color
# markeredgewidth changes the markers stroke size

#lw = linewidth
#ls = linestyle

fig_3 = plt.figure(figsize=(6,4))
axes_3 = fig_3.add_axes([0,0,1,1])

axes_3.plot(x_1, y_1, color="navy" , alpha=0.75,
            lw=2, ls="-.", marker="o", markersize=7,
            markerfacecolor="yellow", markeredgecolor="y", markeredgewidth=4)

plt.show()

# %% [markdown]
# Quiero hacer un zoom

# %%
fig_3 = plt.figure(figsize=(6,4))
axes_3 = fig_3.add_axes([0,0,1,1])

axes_3.plot(x_1, y_1, color="navy" , alpha=0.75,
            lw=2, ls="-.", marker="o", markersize=7,
            markerfacecolor="yellow", markeredgecolor="y", markeredgewidth=4)

axes_3.set_xlim([0,3])
axes_3.set_ylim([0,8])

plt.show()

# %% [markdown]
# agrego grid

# %%
fig_3 = plt.figure(figsize=(6,4))
axes_3 = fig_3.add_axes([0,0,1,1])

axes_3.plot(x_1, y_1, color="navy" , alpha=0.75,
            lw=2, ls="-.", marker="o", markersize=7,
            markerfacecolor="yellow", markeredgecolor="y", markeredgewidth=4)

axes_3.set_xlim([0,3])
axes_3.set_ylim([0,8])

axes_3.grid(True, color='0.6', dashes=(5,2,1,2))
axes_3.set_facecolor("#FAEBD7")
plt.show()

# %% [markdown]
# ## Saving to File

# %%
fig_3.savefig("db_data/3rd_plot.png")
fig_3.savefig("db_data/3rd_plot.pdf")

# %% [markdown]
# ## Working with Pandas DataFrame

# %%
ics_df = pd.read_csv("db_data/icecreamsales.csv")
ics_df.head()
# Out:
#    Temperature  Sales
# 0           37    292
# 1           40    228
# 2           49    324
# 3           61    376
# 4           72    440

# %%
ics_df = ics_df.sort_values(by="Temperature")
ics_df.head()
# Out:
#     Temperature  Sales
# 0            37    292
# 1            40    228
# 11           42    320
# 2            49    324
# 10           53    324

# %%
#wtf lo que hace acá, es la media vuelta
np_arr = ics_df.values
x_2 = np_arr[:,0]
y_2 = np_arr[:,1]

fig_4 = plt.figure(figsize=(6,4))
axes_4 = fig_4.add_axes([0,0,1,1])

axes_4.set_xlabel("Temperature")
axes_4.set_ylabel("Ice Cream Sales")
axes_4.set_title("Ice Cream Sales vs Temperature")

axes_4.plot(x_2,y_2)

plt.plot()
# Out:
# []

# %% [markdown]
# Quiero agregar una anotación con una flecha

# %%
#wtf lo que hace acá, es la media vuelta
np_arr = ics_df.values
x_2 = np_arr[:,0]
y_2 = np_arr[:,1]

fig_4 = plt.figure(figsize=(6,4))
axes_4 = fig_4.add_axes([0,0,1,1])

axes_4.set_xlabel("Temperature")
axes_4.set_ylabel("Ice Cream Sales")
axes_4.set_title("Ice Cream Sales vs Temperature")

axes_4.plot(x_2,y_2)

axes_4.annotate("Good Month", xy=(83,536), xytext=(60,520), 
                arrowprops=dict(facecolor="k", shrink=0.05))
plt.plot()
# Out:
# []

# %% [markdown]
# Agregemos un bar chat abajo

# %%
#wtf lo que hace acá, es la media vuelta
np_arr = ics_df.values
x_2 = np_arr[:,0]
y_2 = np_arr[:,1]

fig_4 = plt.figure(figsize=(6,4))
axes_4 = fig_4.add_axes([0,0,1,1])

axes_4.set_xlabel("Temperature")
axes_4.set_ylabel("Ice Cream Sales")
axes_4.set_title("Ice Cream Sales vs Temperature")

axes_4.plot(x_2,y_2)

axes_4.annotate("Good Month", xy=(83,536), xytext=(60,520), 
                arrowprops=dict(facecolor="k", shrink=0.05))
axes_4.bar(x_2,y_2, color="r", alpha=0.1)
plt.plot()
# Out:
# []

# %% [markdown]
# ## TeX Markup

# %%
fig_5 = plt.figure(figsize=(5,4), dpi=100)
axes_5 = fig_5.add_axes([0.1,0.1,0.9,0.9])

axes_5.text(0, 23, 
            r'$\alpha \beta \sigma \omega \epsilon \mu \pi \theta \lambda$', fontsize=18)
# Subscripts, multiletter superscript, sum, fractions, binomial
axes_5.text(0, 18, 
            r'$\delta_i \gamma^{ij} \sum_{i=0}^\infty x_i \frac{3}{4} \binom{3}{4}$', 
            fontsize=18)
# Another fraction, sqrt, cbrt, trig functions : 
axes_5.text(0, 13, 
            r'$\frac{8 - \frac{x}{5}}{8} \sqrt{9} \sin(\pi) \sqrt[3]{8} \acute a \div$', 
            fontsize=18)
axes_5.text(0, 8, 
            r'$\bar a \hat a \tilde a \vec a \overline {a} \lim_{x \to 2} f(x) = 5$', 
            fontsize=30)
axes_5.text(0, 3, 
            r'$\geq \leq \ne$', 
            fontsize=10, color="r")
axes_5.plot(x_1,y_1)

plt.show()

# matplotlib.org/tutorials/text/mathtext.html

# %% [markdown]
# ## Histograms

# %%
arr_1 = np.random.randint(1,7,20000)
arr_2 = np.random.randint(1,7,20000)
arr_3 = arr_1 + arr_2 

# es una simulación de tirar dos dados

plt.hist(arr_3, bins=11, density=True, stacked=True) #density es frequencia
plt.show()

# Bins reprsent the number of options available 2 thru 12 = 11
# Density returns the frequency of each bin
# Range gets tuple with bin range interested in
# cumulative=True use a cumulative distribution
# histtype='step' genrates a line plot
# orientation='horizontal' 
# color='orange' change bar color

# %%
arr_1 = np.random.randint(1,7,20000)
arr_2 = np.random.randint(1,7,20000)
arr_3 = arr_1 + arr_2 

# es una simulación de tirar dos dados

plt.hist(arr_3, bins=11, density=True, stacked=True, range=(2,8), cumulative=True, histtype="step", orientation="horizontal", color="orange") #density es frequencia
plt.show()

# %% [markdown]
# ## Bar Chart

# %%
# Analyze where France gets its electricity from
x = ['Nuclear', 'Hydro', 'Coal', 'Gas', 'Solar', 'Wind', 'Other']
per_1 = [71, 10, 3, 7, 2, 4, 3]
# Chart variance in usage
variance = [8, 3, 1, 3, 1, 2, 1]

plt.bar(x, per_1, color="purple", yerr=variance)
# Out:
# <BarContainer object of 7 artists>

# %%
# Analyze where France gets its electricity from
x = ['Nuclear', 'Hydro', 'Coal', 'Gas', 'Solar', 'Wind', 'Other']
per_1 = [71, 10, 3, 7, 2, 4, 3]

plt.barh(x, per_1, color="purple")
plt.show()

# %%
# Show percentages of males & females in engineering
m_eng = (76, 85, 86, 88, 93)
f_eng = (24, 15, 14, 12, 7)

# Get evenly spaced values for each interval
spc = np.arange(5)

# Plot bars for men & women
# Can also add yerr, xerr, 
plt.bar(spc, m_eng, width=0.45, label='Male', edgecolor='k')
plt.bar(spc + 0.45, f_eng, width=0.45, label='Female', edgecolor='r')

# Define x tick names and place in middle of bars
plt.xticks(spc + 0.45 / 2, ('Aero', 'Chem', 'Civil', 'Elec', 'Mech'))

plt.show()
