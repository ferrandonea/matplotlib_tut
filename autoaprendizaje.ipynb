# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as matplotlib

# %%
# datos dummy

data = [
    [1,43],
    [2,45],
    [3,42],
    [4,39],
    [5,38],
    [6,46],
    [7,46],
    [8,41],
    [9,35],
    [10,31],
    [11,38],
    [12,49]
]

# %%
#asumamos que esos datos son el % de aviones atrasados

# %%
#%matplotlib inline
#import matplotlib_inline
#|matplotlib_inline.backend_inline.set_matplotlib_formats('svg')

delay_by_month = pd.DataFrame(data, columns = ["Month", "ArrDelay"])
fig, ax = plt.subplots(figsize = (13.33, 7.5), dpi=96)
bar1 = ax.bar(delay_by_month["Month"], delay_by_month["ArrDelay"], width=0.6, zorder=0)

# %%
fig, ax = plt.subplots(figsize = (13.33, 7.5), dpi=96)
bar1 = ax.bar(delay_by_month["Month"], delay_by_month["ArrDelay"], width=0.6)
# crear ejes
ax.grid(which="major", axis="x", color="#DAD8D7", alpha=0.5, zorder=1)
ax.grid(which="major", axis="y", color="#DAD8D7", alpha=0.5, zorder=1)
plt.show()

# %% [markdown]
# ![image.png](attachment:image-2.png)

# %%
fig, ax = plt.subplots(figsize = (13.33, 7.5), dpi=96)
bar1 = ax.bar(delay_by_month["Month"], delay_by_month["ArrDelay"], width=0.6, zorder=2)
# crear ejes
ax.grid(which="major", axis="both", color="#DAD8D7", alpha=0.5, zorder=1) 
# zorder Set the zorder for the artist. Artists with lower zorder values are drawn first.
plt.show()

# %% [markdown]
# Los kwargs están en https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.grid.html

# %%
fig, ax = plt.subplots(figsize = (13.33, 7.5), dpi=96)
bar1 = ax.bar(delay_by_month["Month"], delay_by_month["ArrDelay"], width=0.6)
ax.grid(which="major", axis="both", color="#DAD8D7", alpha=0.5, zorder=1) 

# formateamos el eje X y los ticks
ax.set_xlabel('Mes del año', fontsize=12, labelpad=10) 
# labelpad: Spacing in points from the Axes bounding box including ticks and tick labels. If None, the previous value is left as is.
ax.xaxis.set_label_position("bottom") # top o bottom
plt.show()

# %%
fig, ax = plt.subplots(figsize = (13.33, 7.5), dpi=96)
bar1 = ax.bar(delay_by_month["Month"], delay_by_month["ArrDelay"], width=0.6)
ax.grid(which="major", axis="both", color="#DAD8D7", alpha=0.5, zorder=1) 

# formateamos el eje X y los ticks
ax.set_xlabel('Mes del año', fontsize=12, labelpad=10) 
ax.xaxis.set_label_position("top") # top o bottom
plt.show()

# %%
fig, ax = plt.subplots(figsize = (13.33, 7.5), dpi=96)
bar1 = ax.bar(delay_by_month["Month"], delay_by_month["ArrDelay"], width=0.6)
ax.grid(which="major", axis="both", color="#DAD8D7", alpha=0.5, zorder=1) 

# formateamos el eje X y los ticks
ax.set_xlabel('Mes del año', fontsize=12, labelpad=10, loc="left") 
#loc -> {'left', 'center', 'right'}, default: rcParams["xaxis.labellocation"] (default: 'center')
ax.xaxis.set_label_position("top") # top o bottom
plt.show()

# %% [markdown]
# Veamos las fuentes que tenemos

# %%
import matplotlib.font_manager
from IPython.core.display import HTML

def make_html(fontname):
    return "<p>{font}: <span style='font-family:{font}; font-size: 24px;'>{font}</p>".format(font=fontname)

code = "\n".join([make_html(font) for font in sorted(set([f.name for f in matplotlib.font_manager.fontManager.ttflist]))])

HTML("<div style='column-count: 2;'>{}</div>".format(code))
# Out:
# <div style='column-count: 2;'><p>.Aqua Kana: <span style='font-family:.Aqua Kana; font-size: 24px;'>.Aqua Kana</p>
# <p>.Keyboard: <span style='font-family:.Keyboard; font-size: 24px;'>.Keyboard</p>
# <p>.New York: <span style='font-family:.New York; font-size: 24px;'>.New York</p>
# <p>.SF Arabic: <span style='font-family:.SF Arabic; font-size: 24px;'>.SF Arabic</p>
# <p>.SF Arabic Rounded: <span style='font-family:.SF Arabic Rounded; font-size: 24px;'>.SF Arabic Rounded</p>
# <p>.SF Compact: <span style='font-family:.SF Compact; font-size: 24px;'>.SF Compact</p>
# <p>.SF Compact Rounded: <span style='font-family:.SF Compact Rounded; font-size: 24px;'>.SF Compact Rounded</p>
# <p>.SF NS Mono: <span style='font-family:.SF NS Mono; font-size: 24px;'>.SF NS Mono</p>
# <p>.SF NS Rounded: <span style='font-family:.SF NS Rounded; font-size: 24px;'>.SF NS Rounded</p>
# <p>.ThonburiUI: <span style='font-family:.ThonburiUI; font-size: 24px;'>.ThonburiUI</p>
# ...

# %%
fig, ax = plt.subplots(figsize = (13.33, 7.5), dpi=96)
bar1 = ax.bar(delay_by_month["Month"], delay_by_month["ArrDelay"], width=0.6)
ax.grid(which="major", axis="both", color="#DAD8D7", alpha=0.5, zorder=1) 

# formateamos el eje X y los ticks
font1 = {'family':'fantasy','color':'blue','size':8}
ax.set_xlabel('Mes del año', labelpad=10, loc="center", fontdict=font1) 

font2 = {'family':'cursive','color':'green','size':20}
ax.set_ylabel('Atrasos (minutos)', labelpad=10, loc="center", fontdict=font2) 
#loc -> {'left', 'center', 'right'}, default: rcParams["xaxis.labellocation"] (default: 'center')
ax.xaxis.set_label_position("bottom") # top o bottom
plt.show()

# %% [markdown]
# Jugando un poco y usando los fonts llegamos a este espertento,
#
# lo de fontdict son estos campos https://matplotlib.org/stable/tutorials/text/text_props.html

# %%
fig, ax = plt.subplots(figsize = (13.33, 7.5), dpi=96)
bar1 = ax.bar(delay_by_month["Month"], delay_by_month["ArrDelay"], width=0.6)
ax.grid(which="major", axis="both", color="#DAD8D7", alpha=0.5, zorder=1) 

# formateamos el eje X y los ticks
font1 = {'family':'Phosphate','color':'blue','size':20, 'weight':'bold', 'rotation': 90}
ax.set_xlabel('Mes del año', labelpad=10, loc="center", fontdict=font1) 

font2 = {'family':'Skia','color':'white','size':20, 'backgroundcolor':'red'}
ax.set_ylabel('Atrasos (minutos)', labelpad=10, loc="center", fontdict=font2) 
#loc -> {'left', 'center', 'right'}, default: rcParams["xaxis.labellocation"] (default: 'center')
ax.xaxis.set_label_position("bottom") # top o bottom
plt.show()

# %% [markdown]
# También se puede jugar con un bbox para hacerlo más horrible

# %%
fig, ax = plt.subplots(figsize = (13.33, 7.5), dpi=96)
bar1 = ax.bar(delay_by_month["Month"], delay_by_month["ArrDelay"], width=0.6)
ax.grid(which="major", axis="both", color="#DAD8D7", alpha=0.5, zorder=1) 

# formateamos el eje X y los ticks
font1 = {'family':'Phosphate','color':'blue','size':20, 'weight':'bold', 'rotation': 90}
boxy = {'boxstyle':'circle','edgecolor':'navy'}
# boxstyle
ax.set_xlabel('Mes del año', labelpad=10,loc="center", fontdict=font1, bbox=boxy) 

font2 = {'family':'Skia','color':'white','size':20}
boxx = {'facecolor':'red', 'edgecolor':'green', 'lw':8, 'pad':9}
ax.set_ylabel('Atrasos (minutos)', labelpad=10, loc="center", fontdict=font2, bbox=boxx) 
#loc -> {'left', 'center', 'right'}, default: rcParams["xaxis.labellocation"] (default: 'center')
ax.xaxis.set_label_position("bottom") # top o bottom
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Más opciones de bbox https://matplotlib.org/stable/api/text_api.html#matplotlib.text.Text.set_bbox

# %% [markdown]
# Ahora volvamos a ponernos serios mejor

# %%
fig, ax = plt.subplots(figsize = (13.33, 7.5), dpi=96)
bar1 = ax.bar(delay_by_month["Month"], delay_by_month["ArrDelay"], width=0.6)
ax.grid(which="major", axis="both", color="#DAD8D7", alpha=0.5, zorder=1) 


font1 = {'family':'Infra','color':'black','size':14}

ax.set_xlabel('Mes del año', labelpad=10, loc="center", fontdict=font1) 
ax.xaxis.set_label_position("bottom") # top o bottom 
ax.set_ylabel('Atrasos (minutos)', labelpad=10, loc="center", fontdict=font1) 
ax.yaxis.set_label_position("left") # left o right

plt.show()

# %%
from matplotlib.ticker import MaxNLocator

fig, ax = plt.subplots(figsize = (13.33, 7.5), dpi=96)
bar1 = ax.bar(delay_by_month["Month"], delay_by_month["ArrDelay"], width=0.6)
ax.grid(which="major", axis="both", color="#DAD8D7", alpha=0.5, zorder=1) 


font1 = {'family':'Infra','color':'black','size':14}

ax.set_xlabel('Mes del año', labelpad=10, loc="center", fontdict=font1) 
ax.xaxis.set_label_position("bottom") # top o bottom 
ax.set_ylabel('Atrasos (minutos)', labelpad=10, loc="center", fontdict=font1) 
ax.yaxis.set_label_position("left") # left o right

#formato de número de los ejes
ax.xaxis.set_major_formatter(lambda s, i : f'{s:,.0f}')
ax.yaxis.set_major_formatter(lambda s, i : f'{s:,.1f}')

#esto arregla los bins de la escala
ax.xaxis.set_major_locator(MaxNLocator(integer=True))
ax.yaxis.set_major_locator(MaxNLocator(integer=True))
plt.show()

# %% [markdown]
# MaxNLocator es una clase de la biblioteca de visualización de datos Matplotlib que se utiliza para configurar los intervalos y los límites de los ejes de un gráfico.
#
# En particular, MaxNLocator se utiliza para establecer el número máximo de divisiones en un eje y forzar la inclusión de valores de inicio y fin en el rango de datos para asegurarse de que los límites del eje estén bien definidos.
#
# Esto es útil porque en algunos casos, Matplotlib puede establecer un número de divisiones de manera predeterminada que no es óptimo para visualizar los datos de manera clara y precisa. Usando MaxNLocator, se pueden configurar manualmente los intervalos del eje y asegurarse de que se muestren todos los datos relevantes en el gráfico.
#
# Por ejemplo, si quieres establecer el número máximo de divisiones en el eje y a 5, puedes hacerlo de la siguiente manera : ax.yaxis.set_major_locator(MaxNLocator(nbins=5))
#
# MaxNLocator(integer=True) es un locator de tipo MaxNLocator que se configura para asegurar que los ticks en el eje y sean números enteros. En otras palabras, esta línea de código fuerza a Matplotlib a mostrar solo valores enteros en el eje y de tu gráfico.
#
# MaxNLocator es una clase de Matplotlib que se utiliza para configurar los intervalos y los límites de los ejes de un gráfico. A continuación, se muestran algunos de los atributos más comunes de la clase MaxNLocator:
#
# atributos:
# * nbins: este atributo establece el número máximo de divisiones en el eje. Por defecto, se establece en MaxNLocator.DEFAULT_NBINS, que es igual a 9.
# * steps: este atributo es una secuencia de los pasos a considerar al elegir los límites y los intervalos del eje. Por defecto, es igual a MaxNLocator.STEP_LOOKUP, que es una secuencia que contiene los siguientes valores: 1, 2, 2.5 y 5.
# * integer: este atributo es un valor booleano que indica si se deben mostrar solo valores enteros en el eje. Por defecto, es igual a False.
# * symmetric: este atributo es un valor booleano que indica si los límites del eje deben ser simétricos. Por defecto, es igual a False.
# * prune: este atributo es un valor booleano que indica si se deben eliminar las etiquetas que se superponen. Por defecto, es igual a True.
# * min_n_ticks: este atributo establece el número mínimo de divisiones en el eje. Por defecto, se establece en MaxNLocator.MIN_N_TICKS, que es igual a 2.

# %%
from matplotlib.ticker import MaxNLocator

fig, ax = plt.subplots(figsize = (13.33, 7.5), dpi=96)
bar1 = ax.bar(delay_by_month["Month"], delay_by_month["ArrDelay"], width=0.6)
ax.grid(which="major", axis="both", color="#DAD8D7", alpha=0.5, zorder=1) 


font1 = {'family':'Infra','color':'black','size':14}

ax.set_xlabel('Mes del año', labelpad=10, loc="center", fontdict=font1) 
ax.xaxis.set_label_position("bottom") # top o bottom 
ax.set_ylabel('Atrasos (minutos)', labelpad=10, loc="center", fontdict=font1) 
ax.yaxis.set_label_position("left") # left o right

#formato de número de los ejes
ax.xaxis.set_major_formatter(lambda s, i : f'{s:,.0f}')
ax.yaxis.set_major_formatter(lambda s, i : f'{s:,.1f}')

#esto arregla los bins de la escala
ax.xaxis.set_major_locator(MaxNLocator(integer=True, symmetric=True))
ax.yaxis.set_major_locator(MaxNLocator(integer=True))
plt.show()

# %%
from matplotlib.ticker import MaxNLocator

fig, ax = plt.subplots(figsize = (13.33, 7.5), dpi=96)
bar1 = ax.bar(delay_by_month["Month"], delay_by_month["ArrDelay"], width=0.6)
ax.grid(which="major", axis="both", color="#DAD8D7", alpha=0.5, zorder=1) 


font1 = {'family':'Infra','color':'black','size':14}

ax.set_xlabel('Mes del año', labelpad=10, loc="center", fontdict=font1) 
ax.xaxis.set_label_position("bottom") # top o bottom 
ax.set_ylabel('Atrasos (minutos)', labelpad=10, loc="center", fontdict=font1) 
ax.yaxis.set_label_position("left") # left o right

#formato de número de los ejes
ax.xaxis.set_major_formatter(lambda s, i : f'{s:,.0f}')
ax.yaxis.set_major_formatter(lambda s, i : f'{s:,.1f}')

#esto arregla los bins de la escala
ax.xaxis.set_major_locator(MaxNLocator(min_n_ticks=30))
ax.yaxis.set_major_locator(MaxNLocator(min_n_ticks=30))
plt.show()

# %%
from matplotlib.ticker import MaxNLocator

fig, ax = plt.subplots(figsize = (13.33, 7.5), dpi=96)
bar1 = ax.bar(delay_by_month["Month"], delay_by_month["ArrDelay"], width=0.6)
ax.grid(which="major", axis="both", color="#DAD8D7", alpha=0.5, zorder=1) 


font1 = {'family':'Infra','color':'black','size':14}

ax.set_xlabel('Mes del año', labelpad=10, loc="center", fontdict=font1) 
ax.xaxis.set_label_position("bottom") # top o bottom 
ax.set_ylabel('Atrasos (minutos)', labelpad=10, loc="center", fontdict=font1) 
ax.yaxis.set_label_position("left") # left o right

#formato de número de los ejes
ax.xaxis.set_major_formatter(lambda s, i : f'{s:,.0f}')
ax.yaxis.set_major_formatter(lambda s, i : f'{s:,.1f}')

#esto arregla los bins de la escala
ax.xaxis.set_major_locator(MaxNLocator(min_n_ticks=3))
ax.yaxis.set_major_locator(MaxNLocator(min_n_ticks=30, integer=True, symmetric=True))
plt.show()

# %%
from matplotlib.ticker import MaxNLocator

fig, ax = plt.subplots(figsize = (13.33, 7.5), dpi=96)
bar1 = ax.bar(delay_by_month["Month"], delay_by_month["ArrDelay"], width=0.6)
ax.grid(which="major", axis="both", color="#DAD8D7", alpha=0.5, zorder=1) 


font1 = {'family':'Infra','color':'black','size':14}

ax.set_xlabel('Mes del año', labelpad=10, loc="center", fontdict=font1) 
ax.xaxis.set_label_position("bottom") # top o bottom 
ax.set_ylabel('Atrasos (minutos)', labelpad=10, loc="center", fontdict=font1) 
ax.yaxis.set_label_position("left") # left o right

#formato de número de los ejes
ax.xaxis.set_major_formatter(lambda s, i : f'{s:,.0f}')
ax.yaxis.set_major_formatter(lambda s, i : f'{s:,.1f}')

#esto arregla los bins de la escala
ax.xaxis.set_major_locator(MaxNLocator(nbins=3))
ax.yaxis.set_major_locator(MaxNLocator(min_n_ticks=30, integer=True, symmetric=True))
plt.show()
